# %%
import random
import math

from IPython.display import display, HTML
def show_html(src):
    return display(HTML(src), metadata=dict(isolated=True))

html_tmpl = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="utf-8">
    <title>{title}</title>
    <style>
    html {{ min-height: 32em; overflow: hidden; }}
    </style>
</head>
<body>
{content}
</body>
</html>"""

def chooseWord(words, num):
    word = words[random.randint(0,len(words))]
    while (len(word)!=num):
        word = words[random.randint(0,len(words))]
        print(word)
    print(word)
    return word

adjText = open('adjectives.txt').read()
verbsText = open('verbs.txt').read()
adjectives = adjText.split()
verbs = verbsText.split()

w = chooseWord(adjectives, 5)
print(w)
# Out:
# smart
# smart
# smart

# %%
import random
import math

from IPython.display import display, HTML
def show_html(src):
    return display(HTML(src), metadata=dict(isolated=True))

html_tmpl = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="utf-8">
    <title>{title}</title>
    <style>
    html {{ min-height: 32em; overflow: hidden; }}
    </style>
</head>
<body>
{content}
</body>
</html>"""

def chooseWord(words, num):
    word = words[random.randint(0,len(words)-1)]
    while (len(word)!=num):
        word = words[random.randint(0,len(words)-1)]
    return word

def mkdiv(content, **kwargs):
    if 'position' not in kwargs:
        kwargs['position'] = 'absolute'
    style_str = ' '.join([": ".join((k.replace('_', '-'), v))+";" for k, v in kwargs.items()])
    return f"<div style='{style_str}'>{content}</div>"


adjText = open('adjectives.txt').read()
verbsText = open('verbs.txt').read()
adjectives = adjText.split()
verbs = verbsText.split()
#    mkdiv(f"too {adjectives[0]} to {verbs[0]}", position="relative",top="300px", left="400px", text_align="left", font_size="22pt", font_family="helvetica",),

#print(chooseWord(adjectives, 5))
my_divs = [
    mkdiv(f"too {chooseWord(adjectives, 5)} to {chooseWord(verbs, 3)}", top="50%", 
                 left="50%", transform="translate(-50%, -50%)", font_size="22pt", font_family="helvetica",),
    mkdiv(f"too {chooseWord(adjectives, 7)} to {chooseWord(verbs, 4)}", top="60%",
                 left="42%", transform="rotate(90deg) translate(-50%, -50%)", font_size="22pt", font_family="helvetica",),
    mkdiv(f"too {chooseWord(adjectives, 6)} to {chooseWord(verbs, 7)}", top="67%",
                 left="50%", transform="rotate(45deg) translate(-50%, -50%)", font_size="22pt", font_family="helvetica"),


]
html_src = html_tmpl.format(title="", content="".join(my_divs))
show_html(html_src)
open("output1.html", "w").write(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title></title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# <div style='top: 50%; left: 50%; transform: translate(-50%, -50%); font-size: 22pt; font-family: helvetica; position: absolute;'>too solid to bid</div><div style='top: 60%; left: 42%; transform: rotate(90deg) translate(-50%, -50%); font-size: 22pt; font-family: helvetica; position: absolute;'>too rundown to sink</div><div style='top: 67%; left: 50%; transform: rotate(45deg) translate(-50%, -50%); font-size: 22pt; font-family: helvetica; position: absolute;'>too entire to undress</div>
# </body>
# </html>
# 681

# %%
import random
import math

from IPython.display import display, HTML
def show_html(src):
    return display(HTML(src), metadata=dict(isolated=True))

html_tmpl = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="utf-8">
    <title>{title}</title>
    <style>
    html {{ min-height: 32em; overflow: hidden; }}
    </style>
</head>
<body>
{content}
</body>
</html>"""

def chooseWord(words, num):
    word = words[random.randint(0,len(words)-1)]
    while (len(word)!=num):
        word = words[random.randint(0,len(words)-1)]
    return word

def mkdiv(content, **kwargs):
    if 'position' not in kwargs:
        kwargs['position'] = 'absolute'
    style_str = ' '.join([": ".join((k.replace('_', '-'), v))+";" for k, v in kwargs.items()])
    return f"<div style='{style_str}'>{content}</div>"


adjText = open('adjectives.txt').read()
verbsText = open('verbs.txt').read()
adjectives = adjText.split()
verbs = verbsText.split()
#    mkdiv(f"too {adjectives[0]} to {verbs[0]}", position="relative",top="300px", left="400px", text_align="left", font_size="22pt", font_family="helvetica",),

#print(chooseWord(adjectives, 5))
my_divs = [
    mkdiv("too ", top="50%", color = "rgb(255,0,0)",
                 left="30%", transform="translate(-50%, -50%)", font_size="22pt", font_family="helvetica",),
    mkdiv(f"{chooseWord(adjectives, 7)}", top="50%", 
                 left="35%", transform="translate(-50%, -50%)", font_size="22pt", width="40px", font_family="helvetica",),
    mkdiv("to ", top="50%", color = "rgb(255,0,0)",
                 left="45%", transform="translate(-50%, -50%)", font_size="22pt", font_family="helvetica",),
    mkdiv(f"{chooseWord(verbs, 5)}", top="50%", 
                 left="50%", transform="translate(-50%, -50%)", font_size="22pt", width="40px", font_family="helvetica",),

    mkdiv(f"too {chooseWord(adjectives, 5)}", top="40%",
                 left="39%", transform="rotate(90deg) translate(-50%, -50%)", font_size="22pt", font_family="helvetica",),
    mkdiv(f"{chooseWord(verbs, 4)}", top="67%",
                 left="41%", transform="rotate(90deg) translate(-50%, -50%)", font_size="22pt", font_family="helvetica"),

    mkdiv(f"{chooseWord(adjectives, 4)} to {chooseWord(verbs, 6)}", top="90%",
                 left="20%", transform="rotate(90deg) translate(-50%, -50%)", font_size="22pt", font_family="helvetica"),

]
html_src = html_tmpl.format(title="", content="".join(my_divs))
show_html(html_src)
open("output2.html", "w").write(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title></title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
import random
import math

from IPython.display import display, HTML
def show_html(src):
    return display(HTML(src), metadata=dict(isolated=True))

html_tmpl = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="utf-8">
    <title>{title}</title>
    <style>
    html {{ min-height: 32em; overflow: hidden; }}
    </style>
</head>
<body>
{content}
</body>
</html>"""

def chooseWord(words, num):
    word = words[random.randint(0,len(words)-1)]
    while (len(word)!=num):
        word = words[random.randint(0,len(words)-1)]
    return word

def mkdiv(content, **kwargs):
    if 'position' not in kwargs:
        kwargs['position'] = 'absolute'
    style_str = ' '.join([": ".join((k.replace('_', '-'), v))+";" for k, v in kwargs.items()])
    return f"<div style='{style_str}'>{content}</div>"


adjText = open('adjectives.txt').read()
verbsText = open('verbs.txt').read()
adjectives = adjText.split()
verbs = verbsText.split()
#    mkdiv(f"too {adjectives[0]} to {verbs[0]}", position="relative",top="300px", left="400px", text_align="left", font_size="22pt", font_family="helvetica",),

#print(chooseWord(adjectives, 5))
my_divs = [
    mkdiv("too ", top="50%", color = "rgb(255,0,0)",
                 left="30%", transform="translate(-50%, -50%)", font_size="22pt", font_family="helvetica",),
    mkdiv(f"{chooseWord(adjectives, 7)}", top="50%", 
                 left="35%", transform="translate(-50%, -50%)", font_size="22pt", width="40px", font_family="helvetica",),
    mkdiv("to ", top="50%", color = "rgb(255,0,0)",
                 left="45%", transform="translate(-50%, -50%)", font_size="22pt", font_family="helvetica",),
    mkdiv(f"{chooseWord(verbs, 5)}", top="50%", 
                 left="50%", transform="translate(-50%, -50%)", font_size="22pt", width="40px", font_family="helvetica",),

    mkdiv(f"too {chooseWord(adjectives, 5)}", top="40%",
                 left="39%", transform="rotate(90deg) translate(-50%, -50%)", font_size="22pt", font_family="helvetica",),
    mkdiv(f"{chooseWord(verbs, 6)}", top="67%",
                 left="41%", transform="rotate(90deg) translate(-50%, -50%)", font_size="22pt", font_family="helvetica"),

    mkdiv(f"too {chooseWord(adjectives, 4)}", top="40%",
                 left="35%", transform="rotate(45deg) translate(-50%, -50%)", font_size="22pt", font_family="helvetica"),
    mkdiv(f"{chooseWord(verbs, 3)}", top="67%",
                 left="50%", transform="rotate(45deg) translate(-50%, -50%)", font_size="22pt", font_family="helvetica"),

]
html_src = html_tmpl.format(title="", content="".join(my_divs))
show_html(html_src)
open("output3.html", "w").write(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title></title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
divs = []
n = 14
src = f"too {chooseWord(adjectives, 4)} to {chooseWord(verbs, 4)} ";
for i in range(len(src)):
    ch = src[i]
    center_x = 50 + (30 * math.cos(i * (math.tau / len(src))))
    #center_y = 50 + (30 * math.sin(i * (math.tau / len(src))))
    for j in range(n):
        degrees = j * (360 / n)
        center_y = 50 + (30 * math.sin(j * (math.tau / len(src))))
        this_div = mkdiv(src[i],
                          position="absolute",
                          top=f"{center_y}vh",
                          left=f"{center_x}vh",
                          width="1em",
                          height="4em",
                          text_align="center",
                          font_size="32px",
                          #transform=f"translate(-50%, -50%) rotate({degrees}deg)"
        )
        divs.append(this_div)
html_src = html_tmpl.format(title="circle", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>circle</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
divs = []
n = 14
src = f"too {chooseWord(adjectives, 6)} to {chooseWord(verbs, 3)} ";
lst = src.split()
for i in range(4):
    center_x = 50 + (30 * math.cos(i))
    #center_y = 50 + (30 * math.sin(i * (math.tau / len(src))))
    for j in range(20):
        degrees = j * (360 / n)
        #center_y = 50 + (30 * math.sin(j * (math.tau / len(src))))
        center_y = 50 + (10 * math.sin(degrees * (math.factorial(6))))
        this_div = mkdiv(lst[i],
                          position="absolute",
                          top=f"{center_y}vh",
                          left=f"{center_x}vh",
                          width="1em",
                          height="8em",
                          text_align="center",
                          font_size="32px",
                          #transform=f"translate(-50%, -50%) rotate({degrees}deg)"
        )
        divs.append(this_div)
html_src = html_tmpl.format(title="circle", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>circle</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
divs = []
n = 10
src = f"too {chooseWord(adjectives, 7)} to {chooseWord(verbs, 4)} ";
lst = src.split()
for i in range(len(lst)):
    center_x = 50 + (20 * math.cos(i))
    #center_y = 50 + (30 * math.sin(i * (math.tau / len(src))))
 #   for j in range(len(src[i])):
  #      degrees = j * (360 / n)
        #center_y = 50 + (30 * math.sin(j * (math.tau / len(src))))
    center_y = 50 + (10 * math.sin(degrees * (math.factorial(30))))
    this_div = mkdiv(lst[i],
                          position="absolute",
                          top=f"{center_y}vh",
                          left=f"{center_x}vh",
                          width="1em",
                          height="8em",
                          text_align="center",
                          font_size="32px",
                          #transform=f"translate(-50%, -50%) rotate({degrees}deg)"
    )
    divs.append(this_div)
html_src = html_tmpl.format(title="circle", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>circle</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# <div style='position: absolute; top: 50.0vh; left: 70.0vh; width: 1em; height: 8em; text-align: center; font-size: 32px;'>too</div><div style='position: absolute; top: 50.0vh; left: 60.8060461173628vh; width: 1em; height: 8em; text-align: center; font-size: 32px;'>anxious</div><div style='position: absolute; top: 50.0vh; left: 41.67706326905715vh; width: 1em; height: 8em; text-align: center; font-size: 32px;'>to</div><div style='position: absolute; top: 50.0vh; left: 30.200150067991093vh; width: 1em; height: 8em; text-align: center; font-size: 32px;'>trap</div>
# </body>
# </html>

# %%
divs = []
n = 360
src = "hire me ";
for i in range(n):
    center_x = 50 + math.cos(i)*30
    center_y = 50 + math.sin(i)*30
    
    this_div = mkdiv(src,
                          position="absolute",
                          top=f"{center_y}vh",
                          left=f"{center_x}vh",
                          width="1em",
                          height="10em",
                          text_align="center",
                          font_size="16px",
                          #transform=f"translate(-50%, -50%) rotate({degrees}deg)"
    )
    divs.append(this_div)
html_src = html_tmpl.format(title="circle", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>circle</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
divs = []
n = 360
src = "hire me ";
for i in range(n):
    center_x = 50 + math.cos(i*3)*30
    center_y = 50 + math.sin(i)*30
    
    this_div = mkdiv(src,
                          position="absolute",
                          top=f"{center_y}vh",
                          left=f"{center_x}vh",
                          width="1em",
                          height="10em",
                          text_align="center",
                          font_size="16px",
                          #transform=f"translate(-50%, -50%) rotate({degrees}deg)"
    )
    divs.append(this_div)
html_src = html_tmpl.format(title="circle", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>circle</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
divs = []
n = 45
src = "hire me ";
for i in range(n):
    center_x = 50 + (1+i)*math.cos(i)
    center_y = 50 + (1+i)*math.sin(i)
    
    this_div = mkdiv(src,
                          position="absolute",
                          top=f"{center_y}vh",
                          left=f"{center_x}vh",
                          width="1em",
                          height="4em",
                          text_align="center",
                          font_size="16px",
                          #transform=f"translate(-50%, -50%) rotate({degrees}deg)"
    )
    divs.append(this_div)
html_src = html_tmpl.format(title="circle", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>circle</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
divs = []
n = 360
src = "hire me ";
for i in range(n):
    center_x = 50 + (1+i)*math.cos(i)/n*40
    center_y = 50 + (1+i)*math.sin(i)/n*40
    
    this_div = mkdiv(src,
                          position="absolute",
                          top=f"{center_x}vh",
                          left=f"{center_y}vh",
                          width="1em",
                          height="10em",
                          text_align="center",
                          font_size="10px",
                          #transform=f"translate(-50%, -50%) rotate({degrees}deg)"
    )
    divs.append(this_div)
html_src = html_tmpl.format(title="circle", content="".join(divs))
show_html(html_src)
open("hireme.html", "w").write(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>circle</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
divs = []
n = 360
src = "hire me ";
for i in range(n):
    center_x = 50 + (i)*math.cos(i)/n*20
    center_y = 50 + (i)*math.sin(i)/n*40
    
    this_div = mkdiv(src,
                          position="absolute",
                          top=f"{center_x}vh",
                          left=f"{center_y}vh",
                          width="1em",
                          height="10em",
                          text_align="center",
                          font_size="10px",
                          #transform=f"translate(-50%, -50%) rotate({i}deg)"
    )
    divs.append(this_div)
html_src = html_tmpl.format(title="blackhole", content="".join(divs))
show_html(html_src)
open("blackhole.html", "w").write(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>blackhole</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
divs = []
n = 800
coef = n/40
src = "hire me ";
this_div = mkdiv("black hole with every CV I have ever sent out",
                 position="absolute",
                 top="25vh",
                 left="70vh",
                 width="20em",
                 height="10em",
                 text_align="center",
                 font_size="22px",
                 transform=f"translate(-50%, -50%)")

divs.append(this_div)
for i in range(n):
    center_x = 60 + (i)*math.cos(i)/n*coef*2
    center_y = 70 + (i)*math.sin(i)/n*coef*3
    
    this_div = mkdiv(src, position="absolute", 
                     top=f"{center_x}vh",
                     left=f"{center_y}vh", 
                     width="1em",
                     height="10em",
                     text_align="center",
                     font_size="10px",
                     transform=f"translate(-50%, -50%) rotate({i}deg)"
    )
    divs.append(this_div)
html_src = html_tmpl.format(title="blackhole", content="".join(divs))
show_html(html_src)
open("blackhole.html", "w").write(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>blackhole</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...

# %%
divs = []
n = 800
coef = n/40
src = "hire me ";
this_div = mkdiv("black hole with every CV I have ever sent out",
                 position="absolute",
                 top="25vh",
                 left="84vh",
                 width="20em",
                 height="10em",
                 text_align="center",
                 font_size="22px",
                 transform=f"translate(-50%, -50%)")

divs.append(this_div)
for i in range(n):
    center_x = 60 + (i)*math.cos(i)/n*coef*2
    center_y = 80 + (i)*math.sin(i)/n*coef*4
    
    this_div = mkdiv(src, position="absolute", 
                     top=f"{center_x}vh",
                     left=f"{center_y}vh", 
                     width="1em",
                     height="10em",
                     text_align="center",
                     font_size="10px",
                     transform=f"translate(-50%, -50%) rotate({i}deg)"
    )
    divs.append(this_div)
html_src = html_tmpl.format(title="blackhole", content="".join(divs))
show_html(html_src)
open("blackhole2.html", "w").write(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>blackhole</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# ...
